# %%
from tests import get_computation_times, get_framework_files
import os

# %%
# %pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.8.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# ...
#   Using cached contourpy-1.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.46.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (156 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# ...
#   Using cached numpy-1.26.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (115 kB)
# ...
#   Using cached Pillow-10.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# ...
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached matplotlib-3.8.2-cp311-cp311-macosx_11_0_arm64.whl (7.5 MB)
# Using cached contourpy-1.2.0-cp311-cp311-macosx_11_0_arm64.whl (243 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.46.0-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
# ...

# %%
import matplotlib.pyplot as plt
from typing import Dict, Tuple

# Function to draw a pie chart
def draw_pie_chart(computation_times: Dict[str, Tuple[int, float]], file_name: str):
    labels = computation_times.keys()
    sizes = [time[1] for time in computation_times.values()]

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.pie(sizes, labels=labels, autopct='%1.1f%%')
    ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

    # add a text with the total time and one with the time of the keyword extraction other
    total_time = sum(sizes)
    
    plt.figtext(0.5, 0.07, f"Total time: {total_time:.8f} s", ha='center', va='center')
    plt.figtext(0.5, 0.03, f"Time of tracked functions: {total_time- computation_times['other'][1]:.8f} s", ha='center', va='center')
    #plt.title("Computation Times Pie Chart")
    plt.show()
    fig.savefig(file_name)

# %%
for file in files:

    #get file name
    filename = os.path.basename(file)
    #remove the extension
    filename = os.path.splitext(filename)[0]
    #get path to graphs folder, the graph folder is in the same directory of the notebook
    graph_folder = os.path.join(os.getcwd(), "graphs")
    #create the folder if it doesn't exist
    if not os.path.exists(graph_folder):
        os.makedirs(graph_folder)
    #create the file name of the graph
    graph_file_name = os.path.join(graph_folder, filename + ".png")

    

    computation_times = get_computation_times(file)
    credoulous_acc_time = computation_times.pop('credulous_acceptance')
    total_time = sum([time[1] for time in computation_times.values()])
    other_time = credoulous_acc_time[1] - total_time
    computation_times['other'] = (0, other_time)



    draw_pie_chart(computation_times, graph_file_name)
# Out:
# Conflict-free sets:
# {frozenset({'3', '0'}), frozenset({'0', '2'}), frozenset({'1', '3'}), frozenset({'0'}), frozenset({'2'}), frozenset({'3'}), frozenset(), frozenset({'1'})}
# a is contained in at least one conflict-free set
# b is contained in at least one conflict-free set
# c is contained in at least one conflict-free set
# d is contained in at least one conflict-free set
# e is not contained in any conflict-free set
# --------------------------------------------------
# Admissible sets:
# {frozenset({'3', '0'}), frozenset({'0', '2'}), frozenset({'1', '3'}), frozenset({'0'}), frozenset({'2'}), frozenset({'3'}), frozenset()}
# a is credously accepted w.r.t. the admissible semantics
# b is credously accepted w.r.t. the admissible semantics
# c is credously accepted w.r.t. the admissible semantics
# d is credously accepted w.r.t. the admissible semantics
# e is not credously accepted w.r.t. the admissible semantics
# --------------------------------------------------
# ...
